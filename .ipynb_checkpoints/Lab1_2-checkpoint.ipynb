# %% [markdown]
# # Lab 1-2 : But
#
# Etre capable de concevoir et réaliser <b>des Robots logiciels ou bots,</b> permettant l'extraction et le stockage des informations (Data) à partir du Web.
#
# # Web Scraping
#
# Le Web Scraping (grattage) est une technique utilisée par les développeurs pour extraire  (littéralement « gratter ») des informations d’un site Internet.
#
# # How Does Web Scraping Work?
# 1. <b>Request-Response: </b>
#     la Lib requests permet de récupérer les pages Web via le protocole http(s)
# 2. <b>Parse and Extract: </b>
#     la Lib BeautifulSoup va analyser ces pages et extraire les données
# 3. <b>Manipulate and save Data: </b> la Lib pandas pour la manipulation et le stockage de ces données.

# %%
# requests: make HTTP requests
# Beautiful: library for parsing HTML and XML documents; in order to extract data.
# Pandas: library for data manipulation.
import  requests
from  bs4 import BeautifulSoup
import  pandas as pd
page=requests.get('https://www.jumia.ma/cles-usb/')
soup=BeautifulSoup(page.content,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="fr">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Clés Usb Maroc | Achat Clés Usb à prix pas cher | Jumia
#   </title>
#   <meta content="product" property="og:type"/>
#   <meta content="Jumia Maroc" property="og:site_name"/>
#   <meta content="Clés Usb Maroc | Achat Clés Usb à prix pas cher | Jumia" property="og:title"/>
#   <meta content="Achetez en ligne votre article Clés Usb pas cher sur Jumia.ma ✔ Meilleur prix au Maroc ✔ Paiement à la livraison ✈ Commandez maintenant !" property="og:description"/>
#   <meta content="/cles-usb/" property="og:url"/>
#   <meta content="https://ma.jumia.is/cms/1_2018/GeneralBanners/jumialogo-x-4.png" property="og:image"/>
#   <meta content="fr_MA" property="og:locale"/>
#   <meta content="ar_MA" property="og:locale:alternate"/>
#   <meta content="Clés Usb Maroc | Achat Clés Usb à prix pas cher | Jumia" name="title"/>
#   <meta content="index,follow" name="robots"/>
#   <meta content="Achetez en ligne votre article Clés Usb pas cher sur Jumia.ma ✔ Meilleur prix au Maroc ✔ Paiement à la livraison ✈ Commandez maintenant !" name="description"/>
#   <link href="android-app://com.jumia.android/JUMIA/MA/c/cles-usb?utm_source=google&amp;utm_medium=organic&amp;adjust_tracker=j1hd8h&amp;adjust_campaign=GOOGLE_SEARCH&amp;adjust_adgroup=https%3A%2F%2Fwww.jumia.ma%2Fcles-usb%2F" rel="alternate"/>
#   <link href="https://www.jumia.ma/cles-usb/" rel="canonical"/>
#   <link href="https://www.jumia.ma/cles-usb/?page=2" rel="next"/>
#   <meta content="1925424897719591" property="fb:app_id"/>
#   <meta content="420277734679018" property="fb:pages"/>
#   <meta content="FCik_MncdEk0N-xv3ueP5YGN8UBYuLj-iKNHB41NEHc" name="google-site-verification"/>
#   <meta content="68063A162BA47EF4169ADE2A026EACE9" name="msvalidate.01"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://www.jumia.ma/assets_he/css/main.4aeb6141.css" rel="stylesheet"/>
#   <link href="https://www.jumia.ma/assets_he/favicon.87f00114.ico" rel="icon" sizes="any" type="image/ico"/>
#   <link href="https://www.jumia.ma/assets_he/favicon.adbd556a.svg" rel="icon" type="image/svg+xml"/>
#   <link href="//bam.nr-data.net" rel="preconnect dns-prefetch"/>
#   <link href="//js-agent.newrelic.com" rel="preconnect dns-prefetch"/>
#   <link href="//www.google-analytics.com" rel="preconnect dns-prefetch"/>
#   <link href="//www.googletagmanager.com" rel="preconnect dns-prefetch"/>
#   <link href="//www.facebook.com" rel="preconnect dns-prefetch"/>
#   <link href="//connect.facebook.net" rel="preconnect dns-prefetch"/>
#   <link href="//static.criteo.net" rel="preconnect dns-prefetch"/>
#   <link href="//sslwidget.criteo.com" rel="preconnect dns-prefetch"/>
#   <link href="//dis.eu.criteo.com" rel="preconnect dns-prefetch"/>
#   <link href="//creativecdn.com" rel="preconnect dns-prefetch"/>
#   <link href="https://ma.jumia.is" rel="dns-prefetch"/>
#  </head>
#  <body>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"b76de0635f","applicationID":"199806356","applicationTime":11.245909,"transactionName":"NVxXYhMHChFYVUELDQwWdkMSEgsPFnVUFgMOVlIWHUY0LWpi","queueTime":0,"ttGuid":"1799e01535c63df6","agentToken":null}; (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={xpid:"UgEEU1NACQoJXFFUBAQB",licenseKey:"b76de0635f",applicationID:"199806356"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(31),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(32),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError";if(!c.disabled){var l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(14),t(13),"addEventListener"in window&&t(7),c.xhrWrappable&&t(15),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){U++,L=g.hash,this[u]=y.now()}function o(){U--,g.hash!==L&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable&&!y.disabled){var x=t(11),b=t(12),E=t(9),R=t(7),O=t(14),T=t(8),S=t(15),P=t(10),M=t("ee"),C=M.get("tracer"),N=t(23);t(17),y.features.spa=!0;var L,U=0;M.on(u,r),b.on(p,r),P.on(p,r),M.on(d,o),b.on(l,o),P.on(l,o),M.buffer([u,d,"xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),S.buffer([u,"new-xhr","send-xhr"+s]),T.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),C.buffer([u,"no-"+u]),P.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,m+s),a(T,m+"-done"),a(P,"new-jsonp"),a(P,"jsonp-end"),a(P,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,N(!0)),w[v]("load",i,N(!0)),w[v]("popstate",function(){i(0,U>1)},N(!0))}},{}],5:[function(t,e,n){function r(){var t=new PerformanceObserver(function(t,e){var n=t.getEntries();s(v,[n])});try{t.observe({entryTypes:["resource"]})}catch(e){}}function o(t){if(s(v,[window.performance.getEntriesByType(w)]),window.performance["c"+p])try{window.performance[h](m,o,!1)}catch(t){}else try{window.performance[h]("webkit"+m,o,!1)}catch(t){}}function i(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var a=t("ee"),s=t("handle"),c=t(14),f=t(13),u=t(6) ...
#   </script>
#   <div id="jm">
#    <div class="banner" data-bnrid="163" data-end="2022-10-19T23:59:00+01:00" style="background:#fb9b04;">
#     <div class="row _no-go -phs">
#      <a class="col16 ar _1168-56" data-creative="https://ma.jumia.is/cms/000_2022/Z-Top-Banners/9-Septembre/MA_W03_Onsite_Livraisongrauite_StickyHeader-Animation.gif" data-id="catalog_category_Jex Banner Desktop" data-name="Jex Banner Desktop" data-position="banner_top" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.ma/mlp-jumia-mall-h-jumia-express/">
#       <img alt="Jex Banner Desktop" class="_ni" data-lazy="" data-src="https://ma.jumia.is/cms/000_2022/Z-Top-Banners/9-Septembre/MA_W03_Onsite_Livraisongrauite_StickyHeader-Animation.gif" src="..."/>
#      </a>
#     </div>
#    </div>
#    <div class="vb row -i-ctr -j-ctr _head -bg-gy05 -gy5">
#     <div class="col3 -df -j-start">
#      <a class="_link -df -i-ctr -or5 -m -fs12" href="/market-place/" rel="noopener" target="_blank">
#       <svg class="ic -f-or5 -maxs" height="16" viewbox="0 0 24 24" width="16">
#        <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#cat-services">
#        </use>
#       </svg>
#       Vendez sur Jumia
#      </a>
#     </div>
#     <div class="col10 -df -j-ctr -fs0">
#      <a class="vent-link" title="Jumia">
#       <svg class="ic" height="24" viewbox="0 0 67 24" width="67">
#        <use xlink:href="https://www.jumia.ma/assets_he/images/i-global.cd8c5f0c.svg#venture-jumia">
#        </use>
#       </svg>
#      </a>
#      <a class="vent-link" href="https://food.jumia.ma/?utm_source=jumia&amp;utm_medium=mall&amp;utm_campaign=venturebar" rel="nofollow noopener" target="_blank" title="Jumia Food ">
#       <svg class="ic" height="24" viewbox="0 0 66 24" width="66">
#        <use xlink:href="https://www.jumia.ma/assets_he/images/i-global.cd8c5f0c.svg#venture-food">
#        </use>
#       </svg>
#      </a>
#      <a class="vent-link" href="https://pay.jumia.ma/?utm_source=jumia&amp;utm_medium=mall&amp;utm_campaign=venturebar" rel="nofollow noopener" target="_blank" title="Jumia Pay">
#       <svg class="ic" height="24" viewbox="0 0 60 24" width="60">
#        <use xlink:href="https://www.jumia.ma/assets_he/images/i-global.cd8c5f0c.svg#venture-pay">
#        </use>
#       </svg>
#      </a>
#      <a class="vent-link" href="https://jumia-services.ma/?utm_source=jumia&amp;utm_medium=mall&amp;utm_campaign=venturebar" rel="nofollow noopener" target="_blank" title="Jumia Logistic Services">
#       <svg class="ic" height="24" viewbox="0 0 108 24" width="108">
#        <use xlink:href="https://www.jumia.ma/assets_he/images/i-global.cd8c5f0c.svg#venture-logistics">
#        </use>
#       </svg>
#      </a>
#      <a class="vent-link" href="https://www.jumia.ma/mlp-jumia-prime/?utm_source=jumia&amp;utm_medium=mall&amp;utm_campaign=venturebar" rel="nofollow noopener" target="_blank" title="Jumia Prime">
#       <svg class="ic" height="24" viewbox="0 0 77 24" width="77">
#        <use xlink:href="https://www.jumia.ma/assets_he/images/i-global.cd8c5f0c.svg#venture-prime">
#        </use>
#       </svg>
#      </a>
#     </div>
#     <div class="col3 -df -j-end -wt -mla -gy5">
#      <a class="-vrl -fs0">
#       <span class="-dif -i-ctr -fs12 -op03">
#        <svg class="ic -mrs" height="16" viewbox="0 0 24 24" width="16">
#         <use xlink:href="https://www.jumia.ma/assets_he/images/i-global.cd8c5f0c.svg#flag-fr">
#         </use>
#        </svg>
#        Français
#       </span>
#      </a>
#      <a class="-vrl -fs0" href="/ar/cles-usb/">
#       <span class="-dif -i-ctr -fs12">
#        <svg class="ic -mrs" height="16" viewbox="0 0 24 24" width="16">
#         <use xlink:href="https://www.jumia.ma/assets_he/images/i-global.cd8c5f0c.svg#flag-ma">
#         </use>
#        </svg>
#        العربية
#       </span>
#      </a>
#     </div>
#    </div>
#    <header class="header">
#     <section class="row -i-ctr -fw-nw -pvm">
#      <div class="col3 -df -i-ctr">
#       <div class="dpdw _tail _auto-w _hov _pleft -df -i-ctr -prs -mra">
#        <input aria-controls="dpdw-flyout-box" aria-haspopup="true" aria-label="Parcourir les catégories" class="tgl" id="dpdw-flyout" role="button" type="checkbox"/>
#        <label class="trig -df -pan" for="dpdw-flyout">
#         <span class="-fsh0">
#          <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#           <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#menu">
#           </use>
#          </svg>
#         </span>
#        </label>
#        <div aria-labelledby="dpdw-flyout" class="box" id="dpdw-flyout-box" role="menu">
#         <div class="inbox">
#          <div class="flyout" role="menu">
#           <a class="itm" href="/epicerie/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#cat-groceries">
#             </use>
#            </svg>
#            <span class="text">
#             Supermarché
#            </span>
#           </a>
#           <a class="itm" href="/beaute-hygiene-sante/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#cat-beauty">
#             </use>
#            </svg>
#            <span class="text">
#             Beauté &amp; Santé
#            </span>
#           </a>
#           <a class="itm" href="/fashion-mode/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#cat-fashion">
#             </use>
#            </svg>
#            <span class="text">
#             Vêtements &amp; Chaussures
#            </span>
#           </a>
#           <a class="itm" href="/maison-cuisine-jardin/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#cat-home">
#             </use>
#            </svg>
#            <span class="text">
#             Maison &amp; Cuisine
#            </span>
#           </a>
#           <a class="itm" href="/telephone-tablette/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#cat-mobile">
#             </use>
#            </svg>
#            <span class="text">
#             Téléphone &amp; Tablette
#            </span>
#           </a>
#           <a class="itm" href="https://www.jumia.ma/mlp-electromenager/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#cat-appliance">
#             </use>
#            </svg>
#            <span class="text">
#             Électroménager
#            </span>
#           </a>
#           <a class="itm" href="/ordinateurs-accessoires-informatique/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#cat-computing">
#             </use>
#            </svg>
#            <span class="text">
#             Informatique
#            </span>
#           </a>
#           <a class="itm" href="/sports-loisirs/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#cat-fitness">
#             </use>
#            </svg>
#            <span class="text">
#             Sports &amp; Loisirs
#            </span>
#           </a>
#           <a class="itm" href="/electronique/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#cat-tv">
#             </use>
#            </svg>
#            <span class="text">
#             TV &amp; Hi Tech
#            </span>
#           </a>
#           <a class="itm" href="/bebe-puericulture/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#cat-baby">
#             </use>
#            </svg>
#            <span class="text">
#             Bébé &amp; Jouets
#            </span>
#           </a>
#           <a class="itm" href="/automobile-outils/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#cat-car">
#             </use>
#            </svg>
#            <span class="text">
#             Accessoire Auto Moto
#            </span>
#           </a>
#           <a class="itm" role="menuitem" tabindex="0">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#cat-othercategories">
#             </use>
#            </svg>
#            <span class="text">
#             Autres catégories
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <a class="-df -i-ctr -mra" href="/">
#        <svg aria-label="Jumia Maroc | Téléphones, TV, PC, Vêtements, Maison, Beauté et plus encore" class="ic" height="30" role="img" viewbox="0 0 172 30" width="134">
#         <use xlink:href="https://www.jumia.ma/assets_he/images/i-shop-jumia.85ab1fc3.svg#logo">
#         </use>
#        </svg>
#       </a>
#      </div>
#      <form action="/catalog/" class="cola -df" data-track-onsubmit="search" id="search" method="get">
#       <div class="find">
#        <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#         <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#search">
#         </use>
#        </svg>
#        <input aria-label="Rechercher" autocomplete="off" id="fi-q" name="q" placeholder="Cherchez un produit, une marque ou une catégorie" required="" type="text" value=""/>
#        <button aria-label="Réinitialiser" class="rst" type="button">
#         <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#          <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#close">
#          </use>
#         </svg>
#        </button>
#        <div class="sug">
#        </div>
#       </div>
#       <button class="btn _prim _md -mls -fsh0">
#        Rechercher
#       </button>
#      </form>
#      <div class="col -df -j-bet -m -phn -i-ctr">
#       <div class="dpdw _pcent">
#        <input aria-controls="dpdw-login-box" aria-haspopup="true" aria-label="Se connecter" class="tgl" id="dpdw-login" role="button" type="checkbox"/>
#        <label class="trig -df -i-ctr -fs16" for="dpdw-login">
#         <span class="-fsh0 -mrs">
#          <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#           <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#person">
#           </use>
#          </svg>
#         </span>
#         Se connecter
#         <svg class="ic -mls -fsh0" height="18" viewbox="0 0 24 24" width="18">
#          <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#arrow-down">
#          </use>
#         </svg>
#        </label>
#        <div aria-labelledby="dpdw-login" class="box -r" id="dpdw-login-box" role="menu">
#         <div class="inbox">
#          <div class="-pam -hr-bb">
#           <a class="btn _prim -fw _md" href="/customer/account/login/?return=%2Fcles-usb%2F">
#            Se connecter
#           </a>
#          </div>
#          <a class="-df -i-ctr -pas -hov-bg-gy05 -hov-m" href="/customer/account/index/">
#           <svg class="ic -mrm -fsh0" height="24" viewbox="0 0 24 24" width="24">
#            <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#person">
#            </use>
#           </svg>
#           Votre compte
#          </a>
#          <a class="-df -i-ctr -pas -hov-bg-gy05 -hov-m" href="/customer/order/index/">
#           <svg class="ic -mrm -fsh0" height="24" viewbox="0 0 24 24" width="24">
#            <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#orders">
#            </use>
#           </svg>
#           Vos commandes
#          </a>
#          <a class="-df -i-ctr -pas -hov-bg-gy05 -hov-m" href="/customer/wishlist/index/">
#           <svg class="ic -mrm -fsh0" height="24" viewbox="0 0 24 24" width="24">
#            <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#favorite-border">
#            </use>
#           </svg>
#           Votre liste d'envies
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="dpdw _pcent">
#        <input aria-controls="dpdw-help-box" aria-haspopup="true" aria-label="Aide" class="tgl" id="dpdw-help" role="button" type="checkbox"/>
#        <label class="trig -df -i-ctr -fs16" for="dpdw-help">
#         <span class="-fsh0 -mrs">
#          <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#           <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#help-outline">
#           </use>
#          </svg>
#         </span>
#         Aide
#         <svg class="ic -mls -fsh0" height="18" viewbox="0 0 24 24" width="18">
#          <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#arrow-down">
#          </use>
#         </svg>
#        </label>
#        <div aria-labelledby="dpdw-help" class="box -r" id="dpdw-help-box" role="menu">
#         <div class="inbox">
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="/aide/">
#           Centre d'assistance
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="/sp-aide-avec-mes-commandes/">
#           Passer et suivre ma commande
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="/sp-annulation-de-commande/">
#           Annuler ma commande
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="/sp-retour-remboursement/">
#           Retour et Remboursement
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="/sp-paiement/">
#           Paiement et compte Jumia
#          </a>
#          <div class="-tac -hr _hx2 -fs0 -pam">
#           <button class="btn _prim _md _i -fw" data-btn-lc="" data-eventaction="open" data-eventcategory="LiveChat" data-track-onclick="">
#            <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#             <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#chat">
#             </use>
#            </svg>
#            <span>
#             Chat en direct
#            </span>
#           </button>
#          </div>
#         </div>
#        </div>
#       </div>
#       <a class="-df -i-ctr -gy8 -hov-or5 -phs -fs16" href="/cart/">
#        <span class="-mrs -fs0" id="ci">
#         <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#          <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#shopping-cart">
#          </use>
#         </svg>
#        </span>
#        Panier
#       </a>
#      </div>
#     </section>
#    </header>
#    <article class="banner _pp" data-ppb-rev="v1.0">
#     <div class="ctt-w">
#      <p class="ctt">
#       Ce site web utilise des cookies. Pour plus d'informations sur la façon dont nous utilisons les cookies, vous pouvez lire notre
#       <a class="_more -fs12" href="/sp-confidentialite/" rel="noopener" target="_blank">
#        Notification sur la  confidentialité et les cookies
#       </a>
#      </p>
#      <button aria-label="Fermer" class="cls">
#       <span class="ic-bg -bg-wt">
#        <svg class="ic -maxs" height="16" viewbox="0 0 24 24" width="16">
#         <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#close">
#         </use>
#        </svg>
#       </span>
#      </button>
#     </div>
#    </article>
#    <main class="has-b2top -pts">
#     <style>
#      .c-prd{order:8;}.c-prd:nth-child(n+0):nth-child(-n+1),.c-prd._spn:nth-last-of-type(1){order: 0;}.c-prd:nth-child(n+2):nth-child(-n+5),.c-prd._spn:nth-last-of-type(2){order: 1;}.c-prd:nth-child(n+6):nth-child(-n+9),.c-prd._spn:nth-last-of-type(3){order: 2;}.c-prd:nth-child(n+10):nth-child(-n+13),.c-prd._spn:nth-last-of-type(4){order: 3;}.c-prd:nth-child(n+14):nth-child(-n+17),.c-prd._spn:nth-last-of-type(5){order: 4;}.c-prd:nth-child(n+18):nth-child(-n+21),.c-prd._spn:nth-last-of-type(6){order: 5;}.c-prd:nth-child(n+22):nth-child(-n+25),.c-prd._spn:nth-last-of-type(7){order: 6;}.c-prd:nth-child(n+26):nth-child(-n+29),.c-prd._spn:nth-last-of-type(8){order: 7;}
#     </style>
#     <div class="row">
#      <div class="brcbs col16 -pvs">
#       <a class="cbs" href="/">
#        Accueil
#       </a>
#       <a class="cbs" href="/ordinateurs-accessoires-informatique/">
#        Informatique
#       </a>
#       <a class="cbs" href="/ordinateurs-imprimantes/">
#        Ordinateurs &amp; Imprimantes
#       </a>
#       <a class="cbs" href="/stockage/">
#        Stockage de données
#       </a>
#       <a class="cbs">
#        Clés USB
#       </a>
#      </div>
#      <div class="col16">
#       <div class="-pvs" data-ad="" id="catalog_top">
#       </div>
#      </div>
#     </div>
#     <div class="aim row -pbm">
#      <div class="hook" id="catalog-listing">
#      </div>
#      <div class="col4 -me-start -pvs">
#       <div class="card -fh">
#        <article>
#         <h2 class="-m -upp -fs14 -pvs -phm">
#          Catégorie
#         </h2>
#         <a class="-db -pvs -phm -hov-bg-gy05" href="/stockage/">
#          Stockage de données
#         </a>
#         <a class="-db -pvs -phxl -hov-bg-gy05" href="/disques-durs-externes/">
#          Disques durs externes
#         </a>
#         <a class="-db -pvs -phxl -hov-bg-gy05" href="/stockage-donnees-disques-durs-externes-etat-solide/">
#          SSD externes
#         </a>
#         <a class="-db -pvs -phxl -hov-bg-gy05" href="/stockage-donnees-lecteurs-zip-externes/">
#          Lecteurs Zip externes
#         </a>
#         <a class="-db -pvs -phxl -hov-bg-gy05 -m" href="/cles-usb/">
#          Clés USB
#         </a>
#        </article>
#        <article class="-phs -bt" data-filterable="1">
#         <header class="-phs -ptxs">
#          <h2 class="-m -upp -fs14 -pvxs">
#           Marque
#          </h2>
#          <div class="-df -i-ctr -rad99 -phs -ba-gy3 -h-32 -mvxs -oh">
#           <svg class="ic -fsh0 -mrs" height="24" viewbox="0 0 24 24" width="24">
#            <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#search">
#            </use>
#           </svg>
#           <input class="-oh -ban -out0 -fs14 -fh -fw -elli" placeholder="Chercher" type="search"/>
#          </div>
#         </header>
#         <div class="-phs -pvxs -df -d-co -h-168 -oya -sc">
#          <a class="fk-cb -me-start -fsh0" data-value="a-general" href="/cles-usb/brand-a-general/#catalog-listing">
#           A-GENERAL
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="adata" href="/cles-usb/adata/#catalog-listing">
#           Adata
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="besr" href="/cles-usb/besr/#catalog-listing">
#           Besr
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="biyetimi" href="/cles-usb/biyetimi/#catalog-listing">
#           Biyetimi
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="combo" href="/cles-usb/combo/#catalog-listing">
#           Combo
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="eaget" href="/cles-usb/eaget/#catalog-listing">
#           Eaget
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="earldom" href="/cles-usb/earldom/#catalog-listing">
#           Earldom
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="edup" href="/cles-usb/edup/#catalog-listing">
#           Edup
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="flash drive" href="/cles-usb/flash-drive/#catalog-listing">
#           Flash Drive
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="general" href="/cles-usb/general/#catalog-listing">
#           General
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="generic" href="/cles-usb/generic/#catalog-listing">
#           Generic
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="gotta" href="/cles-usb/gotta/#catalog-listing">
#           GOTTA
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="hp" href="/cles-usb/hp/#catalog-listing">
#           Hp
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="jaster" href="/cles-usb/jaster/#catalog-listing">
#           JASTER
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="kingston" href="/cles-usb/kingston/#catalog-listing">
#           Kingston
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="kingstone" href="/cles-usb/kingstone/#catalog-listing">
#           Kingstone
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="kingston technology" href="/cles-usb/kingston-technology/#catalog-listing">
#           Kingston Technology
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="kioxia" href="/cles-usb/kioxia/#catalog-listing">
#           KIOXIA
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="kodak" href="/cles-usb/kodak/#catalog-listing">
#           Kodak
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="lacie" href="/cles-usb/lacie/#catalog-listing">
#           Lacie
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="ledger" href="/cles-usb/ledger/#catalog-listing">
#           Ledger
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="lexar" href="/cles-usb/lexar/#catalog-listing">
#           Lexar
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="lin pour l autre" href="/cles-usb/lin-pour-l-autre/#catalog-listing">
#           Lin Pour L Autre
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="maxell" href="/cles-usb/maxell/#catalog-listing">
#           Maxell
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="mercusys" href="/cles-usb/mercusys/#catalog-listing">
#           Mercusys
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="microcell" href="/cles-usb/brand-microcell/#catalog-listing">
#           MICROCELL
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="microchip technology" href="/cles-usb/microchip-technology/#catalog-listing">
#           Microchip Technology
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="microdata" href="/cles-usb/microdata/#catalog-listing">
#           microdata
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="microdrive" href="/cles-usb/microdrive/#catalog-listing">
#           Microdrive
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="netis" href="/cles-usb/netis/#catalog-listing">
#           Netis
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="nmicro technology" href="/cles-usb/nmicro-technology/#catalog-listing">
#           Nmicro Technology
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="philips" href="/cles-usb/philips/#catalog-listing">
#           Philips
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="pny" href="/cles-usb/pny/#catalog-listing">
#           Pny
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="ryval" href="/cles-usb/ryval/#catalog-listing">
#           Ryval
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="samsung" href="/cles-usb/samsung/#catalog-listing">
#           Samsung
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="sandisk" href="/cles-usb/sandisk/#catalog-listing">
#           Sandisk
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="sony" href="/cles-usb/sony/#catalog-listing">
#           Sony
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="stickdrive" href="/cles-usb/stickdrive/#catalog-listing">
#           STICKDRIVE
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="techkey" href="/cles-usb/techkey/#catalog-listing">
#           Techkey
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="teclast" href="/cles-usb/teclast/#catalog-listing">
#           TECLAST
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="tflash" href="/cles-usb/tflash/#catalog-listing">
#           TFLASH
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="toshiba" href="/cles-usb/toshiba/#catalog-listing">
#           Toshiba
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="verbatim" href="/cles-usb/verbatim/#catalog-listing">
#           Verbatim
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="vidvie" href="/cles-usb/vidvie/#catalog-listing">
#           Vidvie
#          </a>
#          <a class="fk-cb -me-start -fsh0" data-value="wansenda" href="/cles-usb/wansenda/#catalog-listing">
#           WANSENDA
#          </a>
#         </div>
#        </article>
#        <article class="-phs -bt">
#         <header class="-phs -ptxs">
#          <h2 class="-m -upp -fs14 -pvxs">
#           Remise
#          </h2>
#         </header>
#         <div class="-phs -pvxs -df -d-co">
#          <a class="fk-cb -me-start -fsh0" href="/cles-usb/?special_price=1#catalog-listing">
#           Articles en promotion seulement
#          </a>
#         </div>
#        </article>
#        <section class="-phm -pbs -bt" data-filter-price="" data-hash="catalog-listing" data-id="price" data-separator="-" data-url="/cles-usb/">
#         <header class="-df -i-ctr -j-bet">
#          <h2 class="-m -upp -fs14 -pvs">
#           Prix (Dhs)
#          </h2>
#          <button class="btn _def -fsh0" data-apply="">
#           OK
#          </button>
#         </header>
#         <div class="pfs-w -mbm">
#          <div class="paint" style="left:0%;width:100%">
#          </div>
#          <input class="ps" max="2600" min="25" name="x" type="range" value="25"/>
#          <input class="ps" max="2600" min="25" name="y" type="range" value="2600"/>
#         </div>
#         <div class="pfi-w">
#          <div class="pi-w">
#           <input class="pi" max="2600" min="25" name="min" placeholder="Min" type="number" value="25"/>
#          </div>
#          <span class="-phs -fs16">
#           -
#          </span>
#          <div class="pi-w">
#           <input class="pi" max="2600" min="25" name="max" placeholder="Max" type="number" value="2600"/>
#          </div>
#         </div>
#        </section>
#        <article class="-phm -bt">
#         <header class="-df -i-ctr -j-bet">
#          <h2 class="-m -upp -fs14 -pvs">
#           Évaluation clients
#          </h2>
#         </header>
#         <div class="-pbxs -df -d-co">
#          <a aria-label="4 étoiles et plus" class="fk-rad -me-start" href="/cles-usb/?rating=4-5#catalog-listing">
#           <div class="stars _s -mrxs">
#            4 out of 5
#            <div class="in" style="width:80%">
#            </div>
#           </div>
#           et plus
#          </a>
#          <a aria-label="3 étoiles et plus" class="fk-rad -me-start" href="/cles-usb/?rating=3-5#catalog-listing">
#           <div class="stars _s -mrxs">
#            3 out of 5
#            <div class="in" style="width:60%">
#            </div>
#           </div>
#           et plus
#          </a>
#          <a aria-label="2 étoiles et plus" class="fk-rad -me-start" href="/cles-usb/?rating=2-5#catalog-listing">
#           <div class="stars _s -mrxs">
#            2 out of 5
#            <div class="in" style="width:40%">
#            </div>
#           </div>
#           et plus
#          </a>
#          <a aria-label="1 étoile et plus" class="fk-rad -me-start" href="/cles-usb/?rating=1-5#catalog-listing">
#           <div class="stars _s -mrxs">
#            1 out of 5
#            <div class="in" style="width:20%">
#            </div>
#           </div>
#           et plus
#          </a>
#         </div>
#        </article>
#        <article class="-phs -bt">
#         <header class="-phs -ptxs">
#          <h2 class="-m -upp -fs14 -pvxs">
#           Expédié depuis
#          </h2>
#         </header>
#         <div class="-phs -pvxs -df -d-co">
#          <a class="fk-cb -me-start -fsh0" href="/cles-usb/?shipped_from=country_local#catalog-listing">
#           Expédié depuis Maroc
#          </a>
#         </div>
#        </article>
#        <article class="-phs -bt">
#         <header class="-phs -ptxs">
#          <h2 class="-m -upp -fs14 -pvxs">
#           Disque dur (GB)
#          </h2>
#         </header>
#         <div class="-phs -pvxs -df -d-co">
#          <a class="fk-cb -me-start -fsh0" href="/cles-usb/?hdd_size=32#catalog-listing">
#           32
#          </a>
#          <a class="fk-cb -me-start -fsh0" href="/cles-usb/?hdd_size=32GB#catalog-listing">
#           32GB
#          </a>
#          <a class="fk-cb -me-start -fsh0" href="/cles-usb/?hdd_size=64GB#catalog-listing">
#           64GB
#          </a>
#         </div>
#        </article>
#        <article class="-phs -bt">
#         <header class="-phs -ptxs">
#          <h2 class="-m -upp -fs14 -pvxs">
#           Système d'exploitation
#          </h2>
#         </header>
#         <div class="-phs -pvxs -df -d-co">
#          <a class="fk-cb -me-start -fsh0" href="/cles-usb/?operating_system=Android#catalog-listing">
#           Android
#          </a>
#         </div>
#        </article>
#       </div>
#      </div>
#      <div class="-pvs col12">
#       <section class="card -fh">
#        <header>
#         <div class="-mh-48px -df -i-ctr -phs -bb">
#          <h1 class="-fs20 -m -elli -phs">
#           Clés Usb
#          </h1>
#          <div class="-mla">
#           <div class="dpdw _pcent">
#            <input aria-controls="dpdw-sort-box" aria-haspopup="true" aria-label="Les plus demandés" class="tgl" id="dpdw-sort" role="button" type="checkbox"/>
#            <label class="trig -df -i-ctr -fs16" for="dpdw-sort">
#             <span class="pfx">
#              Trier par:
#             </span>
#             Les plus demandés
#             <svg class="ic -mls -fsh0" height="18" viewbox="0 0 24 24" width="18">
#              <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#arrow-down">
#              </use>
#             </svg>
#            </label>
#            <div aria-labelledby="dpdw-sort" class="box -zi5 -r" id="dpdw-sort-box" role="menu">
#             <div class="inbox">
#              <a class="-mh-40px -fs14 -df -i-ctr -fw -phm -hov-bg-gy05 -hov-m -m" href="/cles-usb/#catalog-listing">
#               Les plus demandés
#              </a>
#              <a class="-mh-40px -fs14 -df -i-ctr -fw -phm -hov-bg-gy05 -hov-m" href="/cles-usb/?sort=newest#catalog-listing">
#               Nouvel arrivage
#              </a>
#              <a class="-mh-40px -fs14 -df -i-ctr -fw -phm -hov-bg-gy05 -hov-m" href="/cles-usb/?sort=lowest-price#catalog-listing">
#               Prix croissant
#              </a>
#              <a class="-mh-40px -fs14 -df -i-ctr -fw -phm -hov-bg-gy05 -hov-m" href="/cles-usb/?sort=highest-price#catalog-listing">
#               Prix décroissant
#              </a>
#              <a class="-mh-40px -fs14 -df -i-ctr -fw -phm -hov-bg-gy05 -hov-m" href="/cles-usb/?sort=rating#catalog-listing">
#               Les mieux notés
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="-phs -mh-48px -df -j-bet -i-ctr -bb">
#          <p class="-gy5 -phs">
#           571 résultats
#          </p>
#          <div class="-fs0">
#           <a class="-pas -hov-or5" href="/cles-usb/?viewType=list#catalog-listing">
#            <svg aria-label="Liste" class="ic -f-gy5" height="24" viewbox="0 0 24 24" width="24">
#             <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#list-view">
#             </use>
#            </svg>
#           </a>
#           <a class="-pas -hov-or5" href="/cles-usb/?viewType=grid#catalog-listing">
#            <svg aria-label="Grille" class="ic -f-or5" height="24" viewbox="0 0 24 24" width="24">
#             <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#grid-view">
#             </use>
#            </svg>
#           </a>
#          </div>
#         </div>
#        </header>
#        <div class="-paxs row _no-g _4cl-3cm-shs" data-catalog="">
#         <article class="prd _fb col c-prd">
#          <a class="core" data-brand="Generic" data-category="Computing/Computers &amp; Accessories/Data Storage/USB Flash Drives" data-dimension23="33159" data-dimension26="13" data-dimension27="4" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE232EA1H6JWONAFAMZ" data-list="" data-name="Clé USB 3.0 - Haute vitesse - 2To - Stockage de données -" data-position="1" data-price="9.21" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/cle-usb-3.0-haute-vitesse-2to-stockage-de-donnees-generic-mpg1333702.html">
#           <div class="img-c">
#            <img alt="" class="img" data-lazy="" data-src="https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/89/325384/1.jpg?1887" height="208" src="..." width="208"/>
#           </div>
#           <div class="info">
#            <h3 class="name">
#             Clé USB 3.0 - Haute vitesse - 2To - Stockage de données -
#            </h3>
#            <div class="prc">
#             99.00 Dhs
#            </div>
#            <div class="s-prc-w">
#             <div class="old">
#              250.00 Dhs
#             </div>
#             <div class="bdg _dsct _sm">
#              60%
#             </div>
#            </div>
#            <div class="rev">
#             <div class="stars _s">
#              4 out of 5
#              <div class="in" style="width:80%">
#              </div>
#             </div>
#             (13)
#            </div>
#           </div>
#          </a>
#          <footer class="ft">
#           <form action="/cart/products/GE232EA1H6JWONAFAMZ-46934932/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Computing/Computers &amp; Accessories/Data Storage/USB Flash Drives" data-dimension23="33159" data-dimension26="13" data-dimension27="4" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE232EA1H6JWONAFAMZ" data-name="Clé USB 3.0 - Haute vitesse - 2To - Stockage de données -" data-price="9.21" data-simplesku="GE232EA1H6JWONAFAMZ-46934932" data-sku="GE232EA1H6JWONAFAMZ" data-svar="GE232EA1H6JWONAFAMZ-46934932" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post">
#            <button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">
#             Ajouter au panier
#            </button>
#            <input name="csrfToken" type="hidden" value="e511e8090ea06f6ff057c06daebef441"/>
#           </form>
#          </footer>
#         </article>
#         <article class="prd _fb col c-prd">
#          <a class="core" data-brand="Netis" data-category="Computing/Computers &amp; Accessories/Data Storage/USB Flash Drives" data-dimension23="35034" data-dimension26="29" data-dimension27="3.8" data-dimension28="1" data-dimension37="0" data-dimension43="UND_1" data-dimension44="0" data-id="NE690EL13P0YYNAFAMZ" data-list="" data-name="WF2119S mini cle usb wifi 11N 150MBPS ant.detachable" data-position="2" data-price="9.30" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/wf2119s-mini-cle-usb-wifi-11n-150mbps-ant.detachable-netis-mpg91311.html">
#           <div class="img-c">
#            <img alt="" class="img" data-lazy="" data-src="https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/66/672682/1.jpg?0987" height="208" src="..." width="208"/>
#           </div>
#           <div class="info">
#            <h3 class="name">
#             WF2119S mini cle usb wifi 11N 150MBPS ant.detachable
#            </h3>
#            <div class="prc">
#             99.99 Dhs
#            </div>
#            <p class="mpg" data-prc="99.99 Dhs" data-tot="2">
#             offres à partir de
#            </p>
#            <div class="rev">
#             <div class="stars _s">
#              3.8 out of 5
#              <div class="in" style="width:76%">
#              </div>
#             </div>
#             (29)
#            </div>
#            <svg aria-label="Livraison rapide" class="ic xprss" height="10" viewbox="0 0 114 12" width="94">
#             <use xlink:href="https://www.jumia.ma/assets_he/images/i-shop-jumia.85ab1fc3.svg#express">
#             </use>
#            </svg>
#            <p class="shipp">
#             Éligible à la livraison gratuite
#            </p>
#           </div>
#          </a>
#          <footer class="ft">
#           <div class="-df -i-ctr -pr -j-bet" data-add-cart="" data-sku="NE690EL13P0YYNAFAMZ" data-svar="NE690EL13P0YYNAFAMZ-17716604" data-xhr="">
#            <button class="add btn _prim -pea _md" data-trigpopup="" type="button">
#             Ajouter au panier
#            </button>
#           </div>
#          </footer>
#         </article>
#         <article class="prd _fb col c-prd">
#          <a class="core" data-brand="Kingston" data-category="Computing/Computers &amp; Accessories/Data Storage/USB Flash Drives" data-dimension23="35034" data-dimension26="4" data-dimension27="3.8" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="KI119EL098QCFNAFAMZ" data-list="" data-name="Clé USB - 64GB - USB Pour Stockage - USB 3.2 - DataTraveler EXODIA" data-position="3" data-price="9.29" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/cle-usb-64gb-usb-pour-stockage-usb-3.2-datatraveler-exodia-kingston-mpg932956.html">
#           <div class="img-c">
#            <img alt="" class="img" data-lazy="" data-src="https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/15/523935/1.jpg?7285" height="208" src="..." width="208"/>
#           </div>
#           <div class="info">
#            <h3 class="name">
#             Kingston Clé USB - 64GB - USB Pour Stockage - USB 3.2 - DataTraveler EXODIA
#            </h3>
#            <div class="prc">
#             99.90 Dhs
#            </div>
#            <p class="mpg" data-prc="99.90 Dhs" data-tot="2">
#             offres à partir de
#            </p>
#            <div class="rev">
#             <div class="stars _s">
#              3.8 out of 5
#              <div class="in" style="width:76%">
#              </div>
#             </div>
#             (4)
#            </div>
#           </div>
#          </a>
#          <footer class="ft">
#           <div class="-df -i-ctr -pr -j-bet" data-add-cart="" data-sku="KI119EL098QCFNAFAMZ" data-svar="KI119EL098QCFNAFAMZ-54026370" data-xhr="">
#            <button class="add btn _prim -pea _md" data-trigpopup="" type="button">
#             Ajouter au panier
#            </button>
#           </div>
#          </footer>
#         </article>
#         <article class="prd _fb col c-prd">
#          <a class="core" data-brand="Generic" data-category="Computing/Computers &amp; Accessories/Data Storage/USB Flash Drives" data-dimension23="33159" data-dimension26="1" data-dimension27="4" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE232EA0LAMVBNAFAMZ" data-list="" data-name="Clé USB à double connectique pour les appareils USB Type-C, 2To" data-position="4" data-price="12.93" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-cle-usb-a-double-connectique-pour-les-appareils-usb-type-c-2to-53186753.html">
#           <div class="img-c">
#            <img alt="" class="img" data-lazy="" data-src="https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/35/768135/1.jpg?3374" height="208" src="..." width="208"/>
#           </div>
#           <div class="info">
#            <h3 class="name">
#             Clé USB à double connectique pour les appareils USB Type-C, 2To
#            </h3>
#            <div class="prc">
#             139.00 Dhs
#            </div>
#            <div class="s-prc-w">
#             <div class="old">
#              550.00 Dhs
#             </div>
#             <div class="bdg _dsct _sm">
#              75%
#             </div>
#            </div>
#            <div class="rev">
#             <div class="stars _s">
#              4 out of 5
#              <div class="in" style="width:80%">
#              </div>
#             </div>
#             (1)
#            </div>
#           </div>
#          </a>
#          <footer class="ft">
#           <form action="/cart/products/GE232EA0LAMVBNAFAMZ-53006809/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Computing/Computers &amp; Accessories/Data Storage/USB Flash Drives" data-dimension23="33159" data-dimension26="1" data-dimension27="4" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE232EA0LAMVBNAFAMZ" data-name="Clé USB à double connectique pour les appareils USB Type-C, 2To" data-price="12.93" data-simplesku="GE232EA0LAMVBNAFAMZ-53006809" data-sku="GE232EA0LAMVBNAFAMZ" data-svar="GE232EA0LAMVBNAFAMZ-53006809" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post">
# ...
#         Koton
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/brand-loreal-paris/">
#         L'Oréal Paris
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/lattafa/">
#         Lattafa
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/lenovo/">
#         Lenovo
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/logitech/">
#         Logitech
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/maybelline-new-york/">
#         Maybelline New York
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/moulinex/">
#         Moulinex
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/nespresso/">
#         Nespresso
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/nike/">
#         Nike
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/nintendo/">
#         Nintendo
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/nivea/">
#         NIVEA
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/nokia/">
#         Nokia
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/now-foods/">
#         Now Foods
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/oppo/">
#         Oppo
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/oraimo/">
#         Oraimo
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/oral-b/">
#         Oral B
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/oriflame/">
#         Oriflame
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/philips/">
#         Philips
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/polaris/">
#         Polaris
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/proficook/">
#         Proficook
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/reebok/">
#         Reebok
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/reef/">
#         Reef
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/remax/">
#         Remax
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/remington/">
#         Remington
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/revolution/">
#         Revolution
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/samsung/">
#         Samsung
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/shein/">
#         SHEIN
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/solaray/">
#         Solaray
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/solgar/">
#         Solgar
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/sony/">
#         Sony
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/taurus/">
#         Taurus
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/us-polo/">
#         US POLO
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/xiaomi/">
#         XIAOMI
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="vb row -i-ctr -j-ctr _foot _gy7 -hr -gy3 -mtl">
#      <div class="col3 -df -j-start">
#      </div>
#      <div class="col10 -df -j-ctr -fs0">
#       <a class="vent-link" href="https://food.jumia.ma/?utm_source=jumia&amp;utm_medium=mall&amp;utm_campaign=venturebar" rel="nofollow noopener" target="_blank" title="Jumia Food ">
#        <svg class="ic" height="24" viewbox="0 0 66 24" width="66">
#         <use xlink:href="https://www.jumia.ma/assets_he/images/i-global.cd8c5f0c.svg#venture-food">
#         </use>
#        </svg>
#       </a>
#       <a class="vent-link" href="https://pay.jumia.ma/?utm_source=jumia&amp;utm_medium=mall&amp;utm_campaign=venturebar" rel="nofollow noopener" target="_blank" title="Jumia Pay">
#        <svg class="ic" height="24" viewbox="0 0 60 24" width="60">
#         <use xlink:href="https://www.jumia.ma/assets_he/images/i-global.cd8c5f0c.svg#venture-pay">
#         </use>
#        </svg>
#       </a>
#       <a class="vent-link" href="https://jumia-services.ma/?utm_source=jumia&amp;utm_medium=mall&amp;utm_campaign=venturebar" rel="nofollow noopener" target="_blank" title="Jumia Logistic Services">
#        <svg class="ic" height="24" viewbox="0 0 108 24" width="108">
#         <use xlink:href="https://www.jumia.ma/assets_he/images/i-global.cd8c5f0c.svg#venture-logistics">
#         </use>
#        </svg>
#       </a>
#       <a class="vent-link" href="https://www.jumia.ma/mlp-jumia-prime/?utm_source=jumia&amp;utm_medium=mall&amp;utm_campaign=venturebar" rel="nofollow noopener" target="_blank" title="Jumia Prime">
#        <svg class="ic" height="24" viewbox="0 0 77 24" width="77">
#         <use xlink:href="https://www.jumia.ma/assets_he/images/i-global.cd8c5f0c.svg#venture-prime">
#         </use>
#        </svg>
#       </a>
#      </div>
#      <div class="col3 -df -j-end -wt -mla">
#       <a class="-vrl -fs0 _gy7">
#        <span class="-dif -i-ctr -fs12 -op03">
#         <svg class="ic -mrs" height="16" viewbox="0 0 24 24" width="16">
#          <use xlink:href="https://www.jumia.ma/assets_he/images/i-global.cd8c5f0c.svg#flag-fr">
#          </use>
#         </svg>
#         Français
#        </span>
#       </a>
#       <a class="-vrl -fs0 _gy7" href="/ar/cles-usb/">
#        <span class="-dif -i-ctr -fs12">
#         <svg class="ic -mrs" height="16" viewbox="0 0 24 24" width="16">
#          <use xlink:href="https://www.jumia.ma/assets_he/images/i-global.cd8c5f0c.svg#flag-ma">
#          </use>
#         </svg>
#         العربية
#        </span>
#       </a>
#      </div>
#     </div>
#    </footer>
#    <div class="banner-pop" data-bnrid="179" data-end="2022-10-19T23:59:00+01:00">
#     <a class="-fw -fh" data-creative="https://ma.jumia.is/cms/000_2022/100002-T1-BF22/Vote-Deals/PU/_Vote-PU.gif" data-id="catalog_category_BF22 Teasing Votes" data-name="BF22 Teasing Votes" data-position="banner_normal" data-set-cookie="https://www.jumia.ma/sp-vote-black-friday/" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.ma/sp-vote-black-friday/">
#      <img alt="BF22 Teasing Votes" class="-fw -fh" data-lazy="" data-src="https://ma.jumia.is/cms/000_2022/100002-T1-BF22/Vote-Deals/PU/_Vote-PU.gif" src="..."/>
#     </a>
#     <button aria-label="Fermer la bannière" class="cls">
#      <span class="ic-bg -bg-wt">
#       <svg class="ic -maxs" height="16" viewbox="0 0 24 24" width="16">
#        <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#close">
#        </use>
#       </svg>
#      </span>
#     </button>
#    </div>
#    <div id="pop">
#     <div aria-hidden="false" aria-label="newsletter_popup_close-cta" aria-modal="true" class="popup _open _l" data-pop="" data-pop-id="newsletter" role="dialog">
#      <section aria-labelledby="pop-ttl" class="cw">
#       <button aria-label="newsletter_popup_close-cta" class="cls">
#        <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#         <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#close">
#         </use>
#        </svg>
#       </button>
#       <h2 class="ttl -vh-sr" id="pop-ttl">
#        Bienvenue sur le plus grand Mall au Maroc
#       </h2>
#       <div class="cont _nl">
#        <div class="-df">
#         <div class="-fsh0" style="width:265px;background:url('https://ma.jumia.is/cms/000_2021/Week13/CI_W14_LP-POP-UP-MODAL-NL.png') top/cover no-repeat;">
#         </div>
#         <div class="-pvxl -phl -tac -fw">
#          <h2 class="-fs29 -phxl">
#           Bienvenue sur le plus grand Mall au Maroc
#          </h2>
#          <div class="-ptl -phs">
#           <p class="-fs16 -m -pbxs">
#            Faites vos achats en toute confiance
#           </p>
#           Abonnez-vous à notre newsletter maintenant et recevez tous les jours nos meilleures offres !
#          </div>
#          <form action="/newsletter/subscription/default/" class="-ptm -tal" data-eventaction="Subscribed" data-eventcategory="Newsletter Popup" data-track-onnlsuccess="" id="nl-pop-f" method="post">
#           <input name="tagIds" type="hidden" value="7"/>
#           <div class="fi-w -mhs _ic">
#            <input aria-label="E-mail" class="fi" id="fi-nl-pop-email" name="email" placeholder="Entrez votre adresse e-mail" required="" type="email" value=""/>
#            <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#             <use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg#email">
#             </use>
#            </svg>
#           </div>
#           <div class="-df -ptxs -phxs">
#            <button class="-mhxs btn _prim _md -fw" name="gender" value="male">
#             Homme
#            </button>
#            <button class="-mhxs btn _prim _md -fw" name="gender" value="female">
#             Femme
#            </button>
#           </div>
#           <input name="csrfToken" type="hidden" value="e511e8090ea06f6ff057c06daebef441"/>
#          </form>
#         </div>
#        </div>
#       </div>
#      </section>
#     </div>
#    </div>
#   </div>
#   <script>
#    var dataLayer=[{"countryCode":"MA","language":"fr","platform":"desktop","url":"/cles-usb/","pageType":"catalog","pageSubtype":"category","pageKey":"catalog_category","catFilterIds":"1000/1178/1233/1240","catFilterNames":["Informatique","Ordinateurs & Imprimantes","Stockage de données","Clés USB"],"sponsored":{"apiKey":"fad2c907bf5f754443e92ca4347f2aaaf9abb8af0972d67af02abcd6b8e02cb5CPM","userId":"1293213144434430541634f0d08dbbf2","pageId":"Clés USB","pageType":"category"},"pageTitle":"Clés Usb Maroc | Achat Clés Usb à prix pas cher | Jumia","abTests":"SearchABTest:default#Home:A#MLP:B#SearchPerso:Y#Cart:E#AppPDVCatBar:B","joinedPageType":"catalog_category","skus":["GE232EA1H6JWONAFAMZ","NE690EL13P0YYNAFAMZ","KI119EL098QCFNAFAMZ","GE232EA0LAMVBNAFAMZ","GE232EA0YS0E8NAFAMZ","KI119EL1NC1ZMNAFAMZ","TE165EA16C03DNAFAMZ","KI564EA11D6LBNAFAMZ","SA277EL0ANGT6NAFAMZ","TO026EL1DLKG6NAFAMZ","GE232EA0M0N0ONAFAMZ","SA277EA16AHA1NAFAMZ","SA277EA0PIW41NAFAMZ","SA277EA1BE7VKNAFAMZ","GE232EA0HAA1QNAFAMZ","KI119EL0XQBXONAFAMZ","KI047EA0BX30XNAFAMZ","SA277EA1JHXSHNAFAMZ","SA277EA0P3F5HNAFAMZ","ED618EA1F7Q4FNAFAMZ","GE232EA0JXBMXNAFAMZ","PH046EA0CN1C6NAFAMZ","SA277EA102VCTNAFAMZ","SA277EA0TGDG0NAFAMZ","RY871EA065J5YNAFAMZ","SA277EA0AFI75NAFAMZ","KI119EL0QESZ4NAFAMZ","SA277EA1BZJGDNAFAMZ","SA277EL1L71Y8NAFAMZ","KI119EL1IJ0KZNAFAMZ","GE232EA1FAJR3NAFAMZ","SA277EA0UVSK1NAFAMZ","PH046EA1B66FANAFAMZ","SA277EA1BJFDBNAFAMZ","SA277EA1MA57ENAFAMZ","KO599EA164ZGDNAFAMZ","SA277EA1HCJXCNAFAMZ","SA277EA1LDQB1NAFAMZ","KI119EL0DRDH4NAFAMZ","GE232CA0TF9K5NAFAMZ"]}];(function(w,d,s,l,i,f){function go(){w[l]=w[l]||[];w[l].push({"gtm.start":new Date().getTime(),event:"gtm.js"});f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!="dataLayer"?"&l="+l:"";j.async=true;j.src="//www.googletagmanager.com/gtm.js?id="+i+dl;j.addEventListener('load',function(){dataLayer.push({event:'pageView'});(function(){setTimeout((function(){window.dataLayer.push({event:"pageViewLvl2"}),setTimeout((function(){window.dataLayer.push({event:"pageViewLvl3"})}),500)}),500)})()});f.parentNode.insertBefore(j,f);}w.addEventListener("load",go,false);})(window,document,'script','dataLayer','GTM-KS6DC65');
#   </script>
#   <script>
#    window.__STORE__={"view":"Catalog","activeLanguage":"fr","countryCode":"MA","languages":{"fr":{"text":"Français","default":true},"ar":{"text":"العربية","isRTL":true}},"svgFallback":false,"tracking":{"gtm":{"key":"GTM-KS6DC65","url":"/cles-usb/","pageType":"catalog","pageSubtype":"category","pageKey":"catalog_category","catFilterIds":"1000/1178/1233/1240","catFilterNames":["Informatique","Ordinateurs & Imprimantes","Stockage de données","Clés USB"],"sponsored":{"apiKey":"fad2c907bf5f754443e92ca4347f2aaaf9abb8af0972d67af02abcd6b8e02cb5CPM","userId":"1293213144434430541634f0d08dbbf2","pageId":"Clés USB","pageType":"category"}}},"csrfToken":"e511e8090ea06f6ff057c06daebef441","user":{"id":""},"sprites":{"icons":"https://www.jumia.ma/assets_he/images/i-icons.48f69aa0.svg","global":"https://www.jumia.ma/assets_he/images/i-global.cd8c5f0c.svg","shop":"https://www.jumia.ma/assets_he/images/i-jumia.svg"},"liveChat":{"loadingText":"Démarrage du chat...","botImg":"https://www.jumia.ma/assets_he/images/bot.5beef7d8.svg"},"htmlErrors":{"valueMissing":"Champ requis","typeMismatch":"Information invalide","patternMismatch":"Information non valide"},"addToCart":{"common":{"buyNowQtySelection":{"showQtySelector":true,"cartQtyIncreaseCTA":"augmenter la quantité panier","cartQtyDecreaseCTA":"diminuer la quantité panier"}},"default":{"buyNowCTA":"Ajouter au panier","buyNowQtySelection":{"showQtySelector":true,"cartQtyIncreaseCTA":"augmenter la quantité panier","cartQtyDecreaseCTA":"diminuer la quantité panier"},"isXhr":true}},"popups":{"addToCart":{"data":{"buyNowCTA":"Ajouter au panier","buyNowQtySelection":{"showQtySelector":true,"cartQtyIncreaseCTA":"augmenter la quantité panier","cartQtyDecreaseCTA":"diminuer la quantité panier"},"unavailableText":"Actuellement indisponible","viewUrl":"/cart/","continueCTA":"Poursuivre vos achats","viewCTA":"Finaliser la commande","popupTitle":"Veuillez sélectionner une option","closeCTA":"fermer le popup"},"template":"AddToCart"},"newsletter":{"data":{"title":"Bienvenue sur le plus grand Mall au Maroc","closeCTA":"newsletter_popup_close-cta"},"trackingData":{"viewPopup":{"type":"Newsletter"},"closePopup":{"type":"Newsletter"}},"template":"Default","shouldOpen":true,"size":"L","hideTitle":true}},"products":[{"sku":"GE232EA1H6JWONAFAMZ","name":"Clé USB 3.0 - Haute vitesse - 2To - Stockage de données -","displayName":"Clé USB 3.0 - Haute vitesse - 2To - Stockage de données -","brand":"Generic","sellerId":33159,"categories":"Computing/Computers & Accessories/Data Storage/USB Flash Drives","prices":{"rawPrice":"99.00","price":"99.00 Dhs","priceEuro":"9.21","taxEuro":"1.54","oldPrice":"250.00 Dhs","oldPriceEuro":"23.26","discount":"60%"},"rating":{"average":4,"totalRatings":13},"image":"https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/89/325384/1.jpg?1887","url":"/cle-usb-3.0-haute-vitesse-2to-stockage-de-donnees-generic-mpg1333702.html","isBuyable":true,"simples":[{"sku":"GE232EA1H6JWONAFAMZ-46934932","loginUrl":"/customer/account/login/?tkWl=GE232EA1H6JWONAFAMZ-46934932&return=%2Fcles-usb%2F","isBuyable":true,"name":"","prices":{"rawPrice":"99.00","price":"99.00 Dhs","priceEuro":"9.21","taxEuro":"1.54","oldPrice":"250.00 Dhs","oldPriceEuro":"23.26","discount":"60%"}}],"selectedVariation":"GE232EA1H6JWONAFAMZ-46934932"},{"sku":"NE690EL13P0YYNAFAMZ","name":"WF2119S mini cle usb wifi 11N 150MBPS ant.detachable","displayName":"WF2119S mini cle usb wifi 11N 150MBPS ant.detachable","brand":"Netis","sellerId":35034,"isShopExpress":true,"categories":"Computing/Computers & Accessories/Data Storage/USB Flash Drives","prices":{"rawPrice":"99.99","price":"99.99 Dhs","priceEuro":"9.30","taxEuro":"1.55"},"tags":"UND_1","rating":{"average":3.8,"totalRatings":29},"image":"https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/66/672682/1.jpg?0987","url":"/wf2119s-mini-cle-usb-wifi-11n-150mbps-ant.detachable-netis-mpg91311.html","isBuyable":true,"shopExpress":{"title":"Livraison rapide","text ...
#   </script>
#   <script crossorigin="" src="https://www.jumia.ma/assets_he/js/common.06115e7b.js" type="module">
#   </script>
#   <script crossorigin="" src="https://www.jumia.ma/assets_he/js/pages/catalog/index.d2c5e1f7.js" type="module">
#   </script>
#   <script nomodule="" src="https://www.jumia.ma/assets_he/js/common.es5.79a701fa.js">
#   </script>
#   <script nomodule="" src="https://www.jumia.ma/assets_he/js/pages/catalog/index.es5.8862bd0a.js">
#   </script>
#  </body>
# </html>

# %%
week = soup.find_all("div", {"class": "-paxs row _no-g _4cl-3cm-shs"})
print(week)
# Out:
# [<div class="-paxs row _no-g _4cl-3cm-shs" data-catalog=""><article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Computing/Computers &amp; Accessories/Data Storage/USB Flash Drives" data-dimension23="33159" data-dimension26="13" data-dimension27="4" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE232EA1H6JWONAFAMZ" data-list="" data-name="Clé USB 3.0 - Haute vitesse - 2To - Stockage de données -" data-position="1" data-price="9.21" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/cle-usb-3.0-haute-vitesse-2to-stockage-de-donnees-generic-mpg1333702.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/89/325384/1.jpg?1887" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Clé USB 3.0 - Haute vitesse - 2To - Stockage de données -</h3><div class="prc">99.00 Dhs</div><div class="s-prc-w"><div class="old">250.00 Dhs</div><div class="bdg _dsct _sm">60%</div></div><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(13)</div></div></a><footer class="ft"><form action="/cart/products/GE232EA1H6JWONAFAMZ-46934932/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Computing/Computers &amp; Accessories/Data Storage/USB Flash Drives" data-dimension23="33159" data-dimension26="13" data-dimension27="4" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE232EA1H6JWONAFAMZ" data-name="Clé USB 3.0 - Haute vitesse - 2To - Stockage de données -" data-price="9.21" data-simplesku="GE232EA1H6JWONAFAMZ-46934932" data-sku="GE232EA1H6JWONAFAMZ" data-svar="GE232EA1H6JWONAFAMZ-46934932" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Ajouter au panier</button><input name="csrfToken" type="hidden" value="e511e8090ea06f6ff057c06daebef441"/></form></footer></article><article class="prd _fb col c-prd"><a class="core" data-brand="Netis" data-category="Computing/Computers &amp; Accessories/Data Storage/USB Flash Drives" data-dimension23="35034" data-dimension26="29" data-dimension27="3.8" data-dimension28="1" data-dimension37="0" data-dimension43="UND_1" data-dimension44="0" data-id="NE690EL13P0YYNAFAMZ" data-list="" data-name="WF2119S mini cle usb wifi 11N 150MBPS ant.detachable" data-position="2" data-price="9.30" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/wf2119s-mini-cle-usb-wifi-11n-150mbps-ant.detachable-netis-mpg91311.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ma.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/66/672682/1.jpg?0987" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">WF2119S mini cle usb wifi 11N 150MBPS ant.detachable</h3><div class="prc">99.99 Dhs</div><p class="mpg" data-prc="99.99 Dhs" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">3.8 out of 5<div class="in" style="width:76%"></div></div>(29)</div><svg aria-label="Livraison rapide" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.ma/assets_he/images/i-shop-jumia.85ab1fc3.svg#express"></use></svg><p class="shipp">Éligible à la livraison gratuite</p></div></a><footer class="ft"><div class="-df -i-ctr -pr -j-bet" data-add-cart="" data-sku="NE690EL13P0YYNAFAMZ" data-svar="NE690EL13P0YYNAFAMZ-17716604" data-xhr=""><button class="add btn _prim -pea _md" data-trigpopup="" type="button">Ajouter au panier</button></div></footer></article><article class="prd _fb col c-prd"><a class="core" data-brand="Kingston" data-category="Computing/Computers &amp; Accessories/Data Storage/USB Flash Drives" data-dimension23="35034" data-dimension26="4" data-dimension27="3.8" data-dim ...

# %% [raw]
# items=soup.find_all("article", {"class": "prd _fb col c-prd"})
# #print(items[0])
# image=[item.find(class_='core').get_text() for item in items]
#
# print(image)

# %%
weather_stuff=pd.DataFrame(
    {
        'image':image_name,
    }
)
print(weather_stuff)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
#       1 weather_stuff=pd.DataFrame(
#       2     {
# ----> 3         'period':period_names,
#       4         'short_descriptions':short_descriptions,
#       5         'temperatures': temperatures,
#       6     }
#       7 )
#       8 print(weather_stuff)
#
# NameError: name 'period_names' is not defined

# %%
weather_stuff.to_csv('weather_m11_22.csv')

# %%
weather_stuff.to_json('weather_m11_22.json')

# %%
# Return a Numpy representation of the DataFrame.
df = pd.DataFrame({'age':    [ 3,  29],
                   'height': [94, 170],
                   'weight': [31, 115]})
print(df)
# df=df.values
# print(df)

# %%
df=df.values
print(df)

# %%
df = pd.DataFrame({'animal': ['alligator', 'bee', 'falcon', 'lion',
                   'monkey', 'parrot', 'shark', 'whale', 'zebra']})
print(df)

# %%
# retun 5 first data
print(df.head())

# %%
dict = {"country": ["Brazil", "Russia", "India", "China", "South Africa"],
       "capital": ["Brasilia", "Moscow", "New Dehli", "Beijing", "Pretoria"],
       "area(million km²)": [8.516, 17.10, 3.286, 9.597, 1.221],
       "population(million)": [200.4, 143.5, 1252, 1357, 52.98] }

import pandas as pd
stat = pd.DataFrame(dict)
print(stat)
# Out:
#         country    capital  area(million km²)  population(million)
# 0        Brazil   Brasilia              8.516               200.40
# 1        Russia     Moscow             17.100               143.50
# 2         India  New Dehli              3.286              1252.00
# 3         China    Beijing              9.597              1357.00
# 4  South Africa   Pretoria              1.221                52.98

# %%
# Set the index for stat
stat.index = ["BR", "RU", "IN", "CH", "SA"]

# Print out stat with new index values
print(stat)

# %% [markdown]
# # Export to csv format or json format

# %%
stat.to_csv('stat_c1.csv')
stat.to_json('stat_c1.json')

# %% [markdown]
# # Another way to create a DataFrame is by importing a csv file or json file using Pandas. Now, the csv stat.csv is stored and can be imported using pd.read_csv:

# %%
import requests 
from bs4 import BeautifulSoup 
import pandas as pd  
info=[] 
prices=[] 

for i in range(1,11):         
    page = requests.get("https://www.jumia.ma/cles-usb/?page="+str(i))      
    soup = BeautifulSoup(page.content, 'html.parser')      
    items = soup.find_all('div', attrs={'class': 'info'})      
    info=info + [item.find(class_='name').get_text() for item in items]     
    prices=prices + [item.find(class_='prc').get_text() for item in items] 
    print('Web scarping ......... page:',i )
df=pd.DataFrame({
    'nom de telephone':info,
    'prix':prices,
} )
print(df)
df.to_csv('Cle_USB.csv')
# Out:
# Web scarping ......... page: 1
# Web scarping ......... page: 2
# Web scarping ......... page: 3
# Web scarping ......... page: 4
# Web scarping ......... page: 5
# Web scarping ......... page: 6
# Web scarping ......... page: 7
# Web scarping ......... page: 8
# Web scarping ......... page: 9
# Web scarping ......... page: 10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 14>()
#      12     prices=prices + [item.find(class_='prc').get_text() for item in items]
#      13     print('Web scarping ......... page:',i )
# ---> 14 df=pd.DataFrame({
#      15     'nom de telephone':info,
#      16     'prix':prices,
#      17 } )
#      18 print(df)
#      19 df.to_csv('Cle_USB.csv')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
#     496         if not hasattr(x, "dtype") or not isinstance(x.dtype, ExtensionDtype)
#     497         else x.copy()
#     498         for x in arrays
#     499     ]
#     500     # TODO: can we get rid of the dt64tz special case above?
# --> 502 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:120, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     117 if verify_integrity:
#     118     # figure out the index, if necessary
#     119     if index is None:
# --> 120         index = _extract_index(arrays)
#     121     else:
#     122         index = ensure_index(index)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:674, in _extract_index(data)
#     672 lengths = list(set(raw_lengths))
#     673 if len(lengths) > 1:
# --> 674     raise ValueError("All arrays must be of the same length")
#     676 if have_dicts:
#     677     raise ValueError(
#     678         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     679     )
#
# ValueError: All arrays must be of the same length
